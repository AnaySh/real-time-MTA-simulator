# %%
from mta_graph import SubwayGraph
from complexes import ComplexesData
import pandas as pd

complexes = ComplexesData()
mta = SubwayGraph()

# %%
mta.build_graph()

# %%
def get_onboards_data(complex_id):
    from socrata_od_client import get_ridership_data

    # Get weekday ridership for May 2024 at 9am from station 623
    df = get_ridership_data(
        year=2025,
        month=2,
        day_of_week="Tuesday",
        hour_of_day="9",
        origin_station_complex_id=complex_id
    )

    df_ = df.sort_values('estimated_average_ridership', ascending=False)
    return df_

df_onboards_120 = get_onboards_data("120")
df_onboards_120
# Out:
#      year  month day_of_week  hour_of_day  origin_station_complex_id  \
# 157  2025      2     Tuesday            9                        120
# 209  2025      2     Tuesday            9                        120
# 29   2025      2     Tuesday            9                        120
# 110  2025      2     Tuesday            9                        120
# 212  2025      2     Tuesday            9                        120
# ..    ...    ...         ...          ...                        ...
# 189  2025      2     Tuesday            9                        120
# 77   2025      2     Tuesday            9                        120
# 117  2025      2     Tuesday            9                        120
# 119  2025      2     Tuesday            9                        120
# 142  2025      2     Tuesday            9                        120
#
#     origin_station_complex_name  destination_station_complex_id  \
# 157              Bedford Av (L)                             602
# 209              Bedford Av (L)                             610
# 29               Bedford Av (L)                             618
# 110              Bedford Av (L)                             611
# 212              Bedford Av (L)                             164
# ..                          ...                             ...
# 189              Bedford Av (L)                             603
# 77               Bedford Av (L)                             340
# 117              Bedford Av (L)                               3
# 119              Bedford Av (L)                              71
# 142              Bedford Av (L)                             368
#
#                      destination_station_complex_name  \
# 157                  14 St-Union Sq (L,N,Q,R,W,4,5,6)
# 209                   Grand Central-42 St (S,4,5,6,7)
# 29                             14 St (A,C,E)/8 Av (L)
# 110  Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)
# 212                        34 St-Penn Station (A,C,E)
# ..                                                ...
# 189                    149 St-Grand Concourse (2,4,5)
# 77                             Grand Army Plaza (2,3)
# 117                                       30 Av (N,W)
# 119                                          8 Av (N)
# 142                         Morrison Av-Soundview (6)
#
#      estimated_average_ridership
# 157                     324.6645
# 209                     192.6793
# 29                      179.8185
# 110                     116.7937
# 212                     107.6208
# ..                           ...
# 189                       0.2763
# 77                        0.2763
# 117                       0.2733
# 119                       0.2733
# 142                       0.2733
#
# [228 rows x 9 columns]

# %%
# 0 = north/east-bound, 1 = south/west-bound
def get_ordered_stops(line : str, direction: int, return_type : int = 0):
    complex_ids = [int(complexes.get_complex_id_by_gtfs_stop_id(stop[:-1])) for stop in mta.ordered_stops(line, direction)]
    complex_names = [complexes.get_station_name_by_gtfs_id(stop[:-1]) for stop in mta.ordered_stops(line, direction)]
    if return_type == 0:
        return dict(zip(complex_names, complex_ids))
    elif return_type == 1:
        return complex_ids
    else:
        return complex_names

# %%
def get_onboardings(origin_complex_id: str, line: str, direction: int, df_ : any):
    onboardings = 0
    boardings_df = pd.DataFrame(columns=df_.columns)
    stops_on_line = get_ordered_stops(line, direction, 1)

    for i in range(len(df_)):
        print()
        destination_complex_id = str(df_.iloc[i]["destination_station_complex_id"])
        connecting_lines = mta.connecting_lines(origin_complex_id, destination_complex_id)
        
        print(f"Destination complex id: {destination_complex_id}")
        print(f"Connecting lines: {connecting_lines}")

        if len(connecting_lines) > 0:
            if line in connecting_lines:
                stops_after = get_ordered_stops(line, direction, 1)
                stops_after = stops_after[stops_after.index(int(origin_complex_id)) + 1:]

                print(f"Stops after stop {origin_complex_id}: {stops_after}")

                if int(destination_complex_id) in stops_after:
                    print(f"{destination_complex_id} is in {stops_after}")
                    onboardings += df_.iloc[i]["estimated_average_ridership"] / len(connecting_lines)
                    df_tmp = df_.iloc[[i]].copy()
                    df_tmp["estimated_average_ridership"] /= len(connecting_lines)
                    boardings_df =  pd.concat([boardings_df, df_tmp], ignore_index=True)
                else:
                    print(f"{destination_complex_id} is not in stops_after")

        else:
            shortest_paths = mta.all_shortest_paths(origin_complex_id, destination_complex_id)
            print(f"From {origin_complex_id} to {destination_complex_id}, shortest paths: {shortest_paths}")

            total_paths = 0
            num_paths = 0
            for path in shortest_paths:
                connections = mta.connecting_lines(path[0], path[1])
                distance = abs(stops_on_line.index(int(path[0])) - stops_on_line.index(int(path[1])))
                print(f"From {path[0]} to {path[1]}, connections: {connections}, distance: {distance}")
                total_paths += len(connections)
                if line in connections:
                    if int(path[1]) in stops_after:
                        num_paths += 1
            print(f"Total paths: {total_paths}, num paths: {num_paths}")
            if total_paths > 0 and num_paths > 0:
                onboardings += df_.iloc[i]["estimated_average_ridership"] * (num_paths / total_paths)
                df_tmp = df_.iloc[[i]].copy()
                df_tmp["estimated_average_ridership"] *= (num_paths / total_paths)
                boardings_df =  pd.concat([boardings_df, df_tmp], ignore_index=True)

    return onboardings, boardings_df

# %%
obs, df =get_onboardings ("120", "L", 1, df_onboards_120[0:50])
# Out:
# Destination complex id: 602
# Connecting lines: ['L']
# Stops after stop 120: [629, 122, 123, 124, 125, 126, 127, 630, 129, 130, 131, 621, 133, 134, 135, 136, 137, 138]
# 602 is not in stops_after
#
# Destination complex id: 610
# Connecting lines: []
# From 120 to 610, shortest paths: [['120', '602', '610']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 618
# Connecting lines: ['L']
# Stops after stop 120: [629, 122, 123, 124, 125, 126, 127, 630, 129, 130, 131, 621, 133, 134, 135, 136, 137, 138]
# 618 is not in stops_after
#
# Destination complex id: 611
# Connecting lines: []
# From 120 to 611, shortest paths: [['120', '602', '611'], ['120', '601', '611'], ['120', '618', '611'], ['120', '621', '611']]
# From 120 to 602, connections: ['L'], distance: 3
# From 120 to 601, connections: ['L'], distance: 4
# From 120 to 618, connections: ['L'], distance: 5
# From 120 to 621, connections: ['L'], distance: 12
# Total paths: 4, num paths: 1
#
# Destination complex id: 164
# Connecting lines: []
# From 120 to 164, shortest paths: [['120', '618', '164'], ['120', '621', '164']]
# From 120 to 618, connections: ['L'], distance: 5
# From 120 to 621, connections: ['L'], distance: 12
# Total paths: 2, num paths: 1
#
# Destination complex id: 607
# Connecting lines: []
# From 120 to 607, shortest paths: [['120', '602', '607'], ['120', '601', '607']]
# From 120 to 602, connections: ['L'], distance: 3
# From 120 to 601, connections: ['L'], distance: 4
# Total paths: 2, num paths: 0
#
# Destination complex id: 601
# Connecting lines: ['L']
# Stops after stop 120: [629, 122, 123, 124, 125, 126, 127, 630, 129, 130, 131, 621, 133, 134, 135, 136, 137, 138]
# 601 is not in stops_after
#
# Destination complex id: 225
# Connecting lines: []
# From 120 to 225, shortest paths: [['120', '601', '225']]
# From 120 to 601, connections: ['L'], distance: 4
# Total paths: 1, num paths: 0
#
# Destination complex id: 628
# Connecting lines: []
# From 120 to 628, shortest paths: [['120', '602', '628'], ['120', '601', '628'], ['120', '618', '628'], ['120', '621', '628']]
# From 120 to 602, connections: ['L'], distance: 3
# From 120 to 601, connections: ['L'], distance: 4
# From 120 to 618, connections: ['L'], distance: 5
# From 120 to 621, connections: ['L'], distance: 12
# Total paths: 4, num paths: 1
#
# Destination complex id: 119
# Connecting lines: ['L']
# Stops after stop 120: [629, 122, 123, 124, 125, 126, 127, 630, 129, 130, 131, 621, 133, 134, 135, 136, 137, 138]
# 119 is not in stops_after
#
# Destination complex id: 609
# Connecting lines: []
# From 120 to 609, shortest paths: [['120', '601', '609']]
# From 120 to 601, connections: ['L'], distance: 4
# Total paths: 1, num paths: 0
#
# Destination complex id: 612
# Connecting lines: []
# From 120 to 612, shortest paths: [['120', '602', '612'], ['120', '618', '612']]
# From 120 to 602, connections: ['L'], distance: 3
# From 120 to 618, connections: ['L'], distance: 5
# Total paths: 2, num paths: 0
#
# Destination complex id: 623
# Connecting lines: []
# From 120 to 623, shortest paths: [['120', '602', '623'], ['120', '621', '623']]
# From 120 to 602, connections: ['L'], distance: 3
# From 120 to 621, connections: ['L'], distance: 12
# Total paths: 2, num paths: 1
#
# Destination complex id: 118
# Connecting lines: ['L']
# Stops after stop 120: [629, 122, 123, 124, 125, 126, 127, 630, 129, 130, 131, 621, 133, 134, 135, 136, 137, 138]
# 118 is not in stops_after
#
# Destination complex id: 619
# Connecting lines: []
# From 120 to 619, shortest paths: [['120', '602', '619'], ['120', '601', '619']]
# From 120 to 602, connections: ['L'], distance: 3
# From 120 to 601, connections: ['L'], distance: 4
# Total paths: 2, num paths: 0
#
# Destination complex id: 17
# Connecting lines: []
# From 120 to 17, shortest paths: [['120', '602', '17']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 324
# Connecting lines: []
# From 120 to 324, shortest paths: [['120', '601', '324']]
# From 120 to 601, connections: ['L'], distance: 4
# Total paths: 1, num paths: 0
#
# Destination complex id: 613
# Connecting lines: []
# From 120 to 613, shortest paths: [['120', '602', '613']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 624
# Connecting lines: []
# From 120 to 624, shortest paths: [['120', '602', '624'], ['120', '601', '624'], ['120', '618', '624'], ['120', '621', '624']]
# From 120 to 602, connections: ['L'], distance: 3
# From 120 to 601, connections: ['L'], distance: 4
# From 120 to 618, connections: ['L'], distance: 5
# From 120 to 621, connections: ['L'], distance: 12
# Total paths: 4, num paths: 1
#
# Destination complex id: 228
# Connecting lines: []
# From 120 to 228, shortest paths: [['120', '601', '228']]
# From 120 to 601, connections: ['L'], distance: 4
# Total paths: 1, num paths: 0
#
# Destination complex id: 14
# Connecting lines: []
# From 120 to 14, shortest paths: [['120', '602', '14']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 9
# Connecting lines: []
# From 120 to 9, shortest paths: [['120', '602', '9']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 168
# Connecting lines: []
# From 120 to 168, shortest paths: [['120', '618', '168'], ['120', '621', '168']]
# From 120 to 618, connections: ['L'], distance: 5
# From 120 to 621, connections: ['L'], distance: 12
# Total paths: 2, num paths: 1
#
# Destination complex id: 10
# Connecting lines: []
# From 120 to 10, shortest paths: [['120', '602', '10']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 403
# Connecting lines: []
# From 120 to 403, shortest paths: [['120', '602', '403']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 13
# Connecting lines: []
# From 120 to 13, shortest paths: [['120', '602', '13']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 404
# Connecting lines: []
# From 120 to 404, shortest paths: [['120', '602', '404']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 413
# Connecting lines: []
# From 120 to 413, shortest paths: [['120', '602', '413']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 614
# Connecting lines: []
# From 120 to 614, shortest paths: [['120', '601', '614'], ['120', '618', '614'], ['120', '621', '614']]
# From 120 to 601, connections: ['L'], distance: 4
# From 120 to 618, connections: ['L'], distance: 5
# From 120 to 621, connections: ['L'], distance: 12
# Total paths: 3, num paths: 1
#
# Destination complex id: 405
# Connecting lines: []
# From 120 to 405, shortest paths: [['120', '602', '405']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 167
# Connecting lines: []
# From 120 to 167, shortest paths: [['120', '601', '167'], ['120', '618', '167'], ['120', '621', '167']]
# From 120 to 601, connections: ['L'], distance: 4
# From 120 to 618, connections: ['L'], distance: 5
# From 120 to 621, connections: ['L'], distance: 12
# Total paths: 3, num paths: 1
#
# Destination complex id: 399
# Connecting lines: []
# From 120 to 399, shortest paths: [['120', '602', '399']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 397
# Connecting lines: []
# From 120 to 397, shortest paths: [['120', '602', '397']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 169
# Connecting lines: []
# From 120 to 169, shortest paths: [['120', '618', '169'], ['120', '621', '169']]
# From 120 to 618, connections: ['L'], distance: 5
# From 120 to 621, connections: ['L'], distance: 12
# Total paths: 2, num paths: 1
#
# Destination complex id: 409
# Connecting lines: []
# From 120 to 409, shortest paths: [['120', '602', '409']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 165
# Connecting lines: []
# From 120 to 165, shortest paths: [['120', '618', '165'], ['120', '621', '165']]
# From 120 to 618, connections: ['L'], distance: 5
# From 120 to 621, connections: ['L'], distance: 12
# Total paths: 2, num paths: 1
#
# Destination complex id: 16
# Connecting lines: []
# From 120 to 16, shortest paths: [['120', '602', '16']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 276
# Connecting lines: []
# From 120 to 276, shortest paths: [['120', '618', '276']]
# From 120 to 618, connections: ['L'], distance: 5
# Total paths: 1, num paths: 0
#
# Destination complex id: 414
# Connecting lines: []
# From 120 to 414, shortest paths: [['120', '602', '414']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 471
# Connecting lines: []
# From 120 to 471, shortest paths: [['120', '602', '610', '471'], ['120', '602', '611', '471'], ['120', '601', '611', '471'], ['120', '618', '611', '471'], ['120', '621', '611', '471'], ['120', '602', '461', '471'], ['120', '601', '609', '471'], ['120', '601', '616', '471'], ['120', '618', '616', '471'], ['120', '618', '606', '471'], ['120', '629', '606', '471']]
# From 120 to 602, connections: ['L'], distance: 3
# From 120 to 602, connections: ['L'], distance: 3
# From 120 to 601, connections: ['L'], distance: 4
# From 120 to 618, connections: ['L'], distance: 5
# From 120 to 621, connections: ['L'], distance: 12
# From 120 to 602, connections: ['L'], distance: 3
# From 120 to 601, connections: ['L'], distance: 4
# From 120 to 601, connections: ['L'], distance: 4
# From 120 to 618, connections: ['L'], distance: 5
# From 120 to 618, connections: ['L'], distance: 5
# From 120 to 629, connections: ['L'], distance: 1
# Total paths: 11, num paths: 2
#
# Destination complex id: 622
# Connecting lines: []
# From 120 to 622, shortest paths: [['120', '602', '622'], ['120', '621', '622']]
# From 120 to 602, connections: ['L'], distance: 3
# From 120 to 621, connections: ['L'], distance: 12
# Total paths: 2, num paths: 1
#
# Destination complex id: 477
# Connecting lines: []
# From 120 to 477, shortest paths: [['120', '602', '477']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 407
# Connecting lines: []
# From 120 to 407, shortest paths: [['120', '602', '407']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 625
# Connecting lines: []
# From 120 to 625, shortest paths: [['120', '601', '625'], ['120', '621', '625']]
# From 120 to 601, connections: ['L'], distance: 4
# From 120 to 621, connections: ['L'], distance: 12
# Total paths: 2, num paths: 1
#
# Destination complex id: 224
# Connecting lines: []
# From 120 to 224, shortest paths: [['120', '601', '224']]
# From 120 to 601, connections: ['L'], distance: 4
# Total paths: 1, num paths: 0
#
# Destination complex id: 319
# Connecting lines: []
# From 120 to 319, shortest paths: [['120', '601', '319']]
# From 120 to 601, connections: ['L'], distance: 4
# Total paths: 1, num paths: 0
#
# Destination complex id: 318
# Connecting lines: []
# From 120 to 318, shortest paths: [['120', '601', '318']]
# From 120 to 601, connections: ['L'], distance: 4
# Total paths: 1, num paths: 0
#
# Destination complex id: 327
# Connecting lines: []
# From 120 to 327, shortest paths: [['120', '601', '327']]
# From 120 to 601, connections: ['L'], distance: 4
# Total paths: 1, num paths: 0
#
# Destination complex id: 8
# Connecting lines: []
# From 120 to 8, shortest paths: [['120', '602', '8']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
#
# Destination complex id: 398
# Connecting lines: []
# From 120 to 398, shortest paths: [['120', '602', '398']]
# From 120 to 602, connections: ['L'], distance: 3
# Total paths: 1, num paths: 0
# /var/folders/vv/8v01rf7n71748vxd0m5kt_dr0000gn/T/ipykernel_41121/3098349228.py:49: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   boardings_df =  pd.concat([boardings_df, df_tmp], ignore_index=True)

# %%
print("Onboardings: ", obs)
df
# Out:
# Onboardings:  2290.068751515151
#     year month day_of_week hour_of_day origin_station_complex_id  \
# 0   2025     2     Tuesday           9                       120
# 1   2025     2     Tuesday           9                       120
# 2   2025     2     Tuesday           9                       120
# 3   2025     2     Tuesday           9                       120
# 4   2025     2     Tuesday           9                       120
# 5   2025     2     Tuesday           9                       120
# 6   2025     2     Tuesday           9                       120
# 7   2025     2     Tuesday           9                       120
# 8   2025     2     Tuesday           9                       120
# 9   2025     2     Tuesday           9                       120
# 10  2025     2     Tuesday           9                       120
# 11  2025     2     Tuesday           9                       120
# 12  2025     2     Tuesday           9                       120
# 13  2025     2     Tuesday           9                       120
# 14  2025     2     Tuesday           9                       120
# 15  2025     2     Tuesday           9                       120
# 16  2025     2     Tuesday           9                       120
# 17  2025     2     Tuesday           9                       120
# 18  2025     2     Tuesday           9                       120
# 19  2025     2     Tuesday           9                       120
# 20  2025     2     Tuesday           9                       120
# 21  2025     2     Tuesday           9                       120
# 22  2025     2     Tuesday           9                       120
# 23  2025     2     Tuesday           9                       120
# 24  2025     2     Tuesday           9                       120
# 25  2025     2     Tuesday           9                       120
# 26  2025     2     Tuesday           9                       120
# 27  2025     2     Tuesday           9                       120
# 28  2025     2     Tuesday           9                       120
# 29  2025     2     Tuesday           9                       120
# 30  2025     2     Tuesday           9                       120
# 31  2025     2     Tuesday           9                       120
# 32  2025     2     Tuesday           9                       120
# 33  2025     2     Tuesday           9                       120
# 34  2025     2     Tuesday           9                       120
# 35  2025     2     Tuesday           9                       120
# 36  2025     2     Tuesday           9                       120
# 37  2025     2     Tuesday           9                       120
# 38  2025     2     Tuesday           9                       120
# 39  2025     2     Tuesday           9                       120
# 40  2025     2     Tuesday           9                       120
# 41  2025     2     Tuesday           9                       120
# 42  2025     2     Tuesday           9                       120
# 43  2025     2     Tuesday           9                       120
# 44  2025     2     Tuesday           9                       120
# 45  2025     2     Tuesday           9                       120
# 46  2025     2     Tuesday           9                       120
# 47  2025     2     Tuesday           9                       120
# 48  2025     2     Tuesday           9                       120
# 49  2025     2     Tuesday           9                       120
#
#    origin_station_complex_name destination_station_complex_id  \
# 0               Bedford Av (L)                            602
# 1               Bedford Av (L)                            610
# 2               Bedford Av (L)                            618
# 3               Bedford Av (L)                            611
# 4               Bedford Av (L)                            164
# 5               Bedford Av (L)                            607
# 6               Bedford Av (L)                            601
# 7               Bedford Av (L)                            225
# 8               Bedford Av (L)                            628
# 9               Bedford Av (L)                            119
# 10              Bedford Av (L)                            609
# 11              Bedford Av (L)                            612
# 12              Bedford Av (L)                            623
# 13              Bedford Av (L)                            118
# 14              Bedford Av (L)                            619
# 15              Bedford Av (L)                             17
# 16              Bedford Av (L)                            324
# 17              Bedford Av (L)                            613
# 18              Bedford Av (L)                            624
# 19              Bedford Av (L)                            228
# 20              Bedford Av (L)                             14
# 21              Bedford Av (L)                              9
# 22              Bedford Av (L)                            168
# 23              Bedford Av (L)                             10
# 24              Bedford Av (L)                            403
# 25              Bedford Av (L)                             13
# 26              Bedford Av (L)                            404
# 27              Bedford Av (L)                            413
# 28              Bedford Av (L)                            614
# 29              Bedford Av (L)                            405
# 30              Bedford Av (L)                            167
# 31              Bedford Av (L)                            399
# 32              Bedford Av (L)                            397
# 33              Bedford Av (L)                            169
# 34              Bedford Av (L)                            409
# 35              Bedford Av (L)                            165
# 36              Bedford Av (L)                             16
# 37              Bedford Av (L)                            276
# 38              Bedford Av (L)                            414
# 39              Bedford Av (L)                            471
# 40              Bedford Av (L)                            622
# 41              Bedford Av (L)                            477
# 42              Bedford Av (L)                            407
# 43              Bedford Av (L)                            625
# 44              Bedford Av (L)                            224
# 45              Bedford Av (L)                            319
# 46              Bedford Av (L)                            318
# 47              Bedford Av (L)                            327
# 48              Bedford Av (L)                              8
# 49              Bedford Av (L)                            398
#
#                      destination_station_complex_name  \
# 0                    14 St-Union Sq (L,N,Q,R,W,4,5,6)
# 1                     Grand Central-42 St (S,4,5,6,7)
# 2                              14 St (A,C,E)/8 Av (L)
# 3    Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)
# 4                          34 St-Penn Station (A,C,E)
# 5                   34 St-Herald Sq (B,D,F,M,N,Q,R,W)
# 6                          14 St (F,M,1,2,3)/6 Av (L)
# 7                 47-50 Sts-Rockefeller Ctr (B,D,F,M)
# 8                         Fulton St (A,C,J,Z,2,3,4,5)
# 9                                            1 Av (L)
# 10                       Bryant Pk (B,D,F,M)/5 Av (7)
# 11                 Lexington Av-53 St (E,M)/51 St (6)
# 12                           Canal St (J,N,Q,R,W,Z,6)
# 13                                           3 Av (L)
# 14    Broadway-Lafayette St (B,D,F,M)/Bleecker St (6)
# 15                                    Prince St (R,W)
# 16                                     Houston St (1)
# 17                 Lexington Av (N,R,W)/59 St (4,5,6)
# 18  Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortla...
# 19                                        23 St (F,M)
# 20                                        23 St (R,W)
# 21                               57 St-7 Av (N,Q,R,W)
# 22                                    Spring St (C,E)
# 23                                      49 St (N,R,W)
# 24                                          33 St (6)
# 25                                        28 St (R,W)
# 26                                          28 St (6)
# 27                                      Wall St (4,5)
# 28                  59 St-Columbus Circle (A,B,C,D,1)
# 29                                          23 St (6)
# 30                     W 4 St-Wash Sq (A,C,E,B,D,F,M)
# 31                           68 St-Hunter College (6)
# 32                                      86 St (4,5,6)
# 33                                   Canal St (A,C,E)
# 34                                      Spring St (6)
# 35                                        23 St (C,E)
# 36                                     8 St-NYU (R,W)
# 37                                   5 Av/53 St (E,M)
# 38                                Bowling Green (4,5)
# 39                             34 St-Hudson Yards (7)
# 40  Brooklyn Bridge-City Hall (4,5,6)/Chambers St ...
# 41                                          72 St (Q)
# 42                                       Astor Pl (6)
# 43                   Delancey St (F)/Essex St (J,M,Z)
# 44                                          57 St (F)
# 45                                          28 St (1)
# 46                         34 St-Penn Station (1,2,3)
# 47                                Chambers St (1,2,3)
# 48                                 5 Av/59 St (N,R,W)
# 49                                          77 St (6)
#
#     estimated_average_ridership
# 0                    324.664500
# 1                    192.679300
# 2                    179.818500
# 3                     87.595275
# 4                     53.810400
# 5                    102.560000
# 6                     99.806500
# 7                     87.433200
# 8                     65.565750
# 9                     72.175500
# 10                    69.197700
# 11                    67.561200
# 12                    29.714750
# 13                    53.508000
# 14                    53.508000
# 15                    51.009000
# 16                    47.115300
# 17                    45.651000
# 18                    31.508625
# 19                    41.780000
# 20                    39.841700
# 21                    39.837200
# 22                    18.901250
# 23                    34.462300
# 24                    33.006700
# 25                    31.991000
# 26                    28.837300
# 27                    25.224300
# 28                    16.091800
# 29                    22.958200
# 30                    13.426333
# 31                    19.337200
# 32                    19.271500
# 33                     9.564100
# 34                    18.459500
# 35                     8.969850
# 36                    16.836500
# 37                    16.531800
# 38                    15.432500
# 39                    12.419018
# 40                     6.838000
# 41                    12.875500
# 42                    11.757700
# 43                     5.309500
# 44                    10.138500
# 45                     9.263500
# 46                     9.247200
# 47                     9.233000
# 48                     8.673000
# 49                     8.670300

# %%
mta.lines_at_complex_id("621")
# Out:
# ['A', 'C', 'J', 'L', 'Z']

# %%
l_stops = get_ordered_stops("L", 1, 1)

abs(l_stops.index(120) - l_stops.index(621))
# Out:
# 12
