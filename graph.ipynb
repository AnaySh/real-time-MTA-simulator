# %%
import requests, zipfile, io, pandas as pd, networkx as nx

# 2 ── read the three GTFS tables we need
stops       = pd.read_csv("data/gtfs_subway/stops.txt")          # stop_id, stop_name …
trips       = pd.read_csv("data/gtfs_subway/trips.txt")          # trip_id, route_id …
stop_times  = pd.read_csv("data/gtfs_subway/stop_times.txt")     # trip_id, stop_id, stop_sequence …

# %%
# 3 ── map trip → route so we know which line each edge belongs to
trip2route = dict(zip(trips.trip_id, trips.route_id))

# 4 ── build a graph whose
#      • nodes = stop_id with attribute stop_name
#      • edges = consecutive stop pairs, attribute “lines” = list of route_ids serving that edge
G = nx.DiGraph()

# add all stations once
for row in stops.itertuples():
    G.add_node(row.stop_id, stop_name=row.stop_name)

# iterate through every trip’s ordered stops
for trip_id, group in stop_times.groupby("trip_id"):
    route = trip2route[trip_id]
    ordered = group.sort_values("stop_sequence").stop_id.to_list()
    for u, v in zip(ordered[:-1], ordered[1:]):
        if G.has_edge(u, v):
            G[u][v]["lines"].add(route)
        else:
            G.add_edge(u, v, lines={route})

# 5 ── convert each edge’s set to a sorted list for easier JSON serialisation later
for u, v, data in G.edges(data=True):
    data["lines"] = sorted(data["lines"])

# %%
G.nodes
# Out:
# NodeView(('101', '101N', '101S', '103', '103N', '103S', '104', '104N', '104S', '106', '106N', '106S', '107', '107N', '107S', '108', '108N', '108S', '109', '109N', '109S', '110', '110N', '110S', '111', '111N', '111S', '112', '112N', '112S', '113', '113N', '113S', '114', '114N', '114S', '115', '115N', '115S', '116', '116N', '116S', '117', '117N', '117S', '118', '118N', '118S', '119', '119N', '119S', '120', '120N', '120S', '121', '121N', '121S', '122', '122N', '122S', '123', '123N', '123S', '124', '124N', '124S', '125', '125N', '125S', '126', '126N', '126S', '127', '127N', '127S', '128', '128N', '128S', '129', '129N', '129S', '130', '130N', '130S', '131', '131N', '131S', '132', '132N', '132S', '133', '133N', '133S', '134', '134N', '134S', '135', '135N', '135S', '136', '136N', '136S', '137', '137N', '137S', '138', '138N', '138S', '139', '139N', '139S', '140', '140N', '140S', '142', '142N', '142S', '201', '201N', '201S', '204', '204N', '204S', '205', '205N', '205S', '206', '206N', '206S', '207', '207N', '207S', '208', '208N', '208S', '209', '209N', '209S', '210', '210N', '210S', '211', '211N', '211S', '212', '212N', '212S', '213', '213N', '213S', '214', '214N', '214S', '215', '215N', '215S', '216', '216N', '216S', '217', '217N', '217S', '218', '218N', '218S', '219', '219N', '219S', '220', '220N', '220S', '221', '221N', '221S', '222', '222N', '222S', '224', '224N', '224S', '225', '225N', '225S', '226', '226N', '226S', '227', '227N', '227S', '228', '228N', '228S', '229', '229N', '229S', '230', '230N', '230S', '231', '231N', '231S', '232', '232N', '232S', '233', '233N', '233S', '234', '234N', '234S', '235', '235N', '235S', '236', '236N', '236S', '237', '237N', '237S', '238', '238N', '238S', '239', '239N', '239S', '241', '241N', '241S', '242', '242N', '242S', '243', '243N', '243S', '244', '244N', '244S', '245', '245N', '245S', '246', '246N', '246S', '247', '247N', '247S', '248', '248N', '248S', '249', '249N', '249S', '250', '250N', '250S', '251', '251N', '251S', '252', '252N', '252S', '253', '253N', '253S', '254', '254N', '254S', '255', '255N', '255S', '256', '256N', '256S', '257', '257N', '257S', '301', '301N', '301S', '302', '302N', '302S', '401', '401N', '401S', '402', '402N', '402S', '405', '405N', '405S', '406', '406N', '406S', '407', '407N', '407S', '408', '408N', '408S', '409', '409N', '409S', '410', '410N', '410S', '411', '411N', '411S', '412', '412N', '412S', '413', '413N', '413S', '414', '414N', '414S', '415', '415N', '415S', '416', '416N', '416S', '418', '418N', '418S', '419', '419N', '419S', '420', '420N', '420S', '423', '423N', '423S', '501', '501N', '501S', '502', '502N', '502S', '503', '503N', '503S', '504', '504N', '504S', '505', '505N', '505S', '601', '601N', '601S', '602', '602N', '602S', '603', '603N', '603S', '604', '604N', '604S', '606', '606N', '606S', '607', '607N', '607S', '608', '608N', '608S', '609', '609N', '609S', '610', '610N', '610S', '611', '611N', '611S', '612', '612N', '612S', '613', '613N', '613S', '614', '614N', '614S', '615', '615N', '615S', '616', '616N', '616S', '617', '617N', '617S', '618', '618N', '618S', '619', '619N', '619S', '621', '621N', '621S', '622', '622N', '622S', '623', '623N', '623S', '624', '624N', '624S', '625', '625N', '625S', '626', '626N', '626S', '627', '627N', '627S', '628', '628N', '628S', '629', '629N', '629S', '630', '630N', '630S', '631', '631N', '631S', '632', '632N', '632S', '633', '633N', '633S', '634', '634N', '634S', '635', '635N', '635S', '636', '636N', '636S', '637', '637N', '637S', '638', '638N', '638S', '639', '639N', '639S', '640', '640N', '640S', '701', '701N', '701S', '702', '702N', '702S', '705', '705N', '705S', '706', '706N', '706S', '707', '707N', '707S', '708', '708N', '708S', '709', '709N', '709S', '710', '710N', '710S', '711', '711N', '711S', '712', '712N', '712S', '713', '713N', '713S', '714', '714N', '714S', '715', '715N', '715S', '716', '716N', '716S', '718', '718N', '718S', '719', '719N', '719S', '720', '720N', '720S', '721', '721N', '721S', '723', '723 ...

# %%
lookup_sid   = dict(zip(stops.stop_name, stops.stop_id))
lookup_name  = dict(zip(stops.stop_id, stops.stop_name))

# %%
lookup_name["L01S"]
# Out:
# '8 Av'

# %%
print(lookup_sid["1 Av"])
print(lookup_sid["Bedford Av"])
# Out:
# L06S
# L08S

# %%
u = "L01S"
G[u]
# Out:
# AtlasView({'L02S': {'lines': ['L']}})

# %%
lookup_name["L06N"]
# Out:
# '1 Av'

# %%
def ordered_stops(route: str, direction: int) -> list[str]:
    """Return the list of stop_ids (SIDs) for this line and direction (0=north/east, 1=south/west)."""
    # 1 – pick any trip that matches
    trip_id = trips.query("route_id==@route and direction_id==@direction").trip_id.iloc[0]
    # 2 – grab its ordered stop_ids
    return (stop_times.query("trip_id==@trip_id")
                       .sort_values("stop_sequence")
                       .stop_id
                       .tolist())

# %%
route = "L"
direction = 1

trips.query(
            "route_id==@route and direction_id==@direction"
        )
# Out:
#       route_id                                   trip_id service_id  \
# 10736        L  BFA24GEN-L026-Saturday-00_005400_L..S01R   Saturday
# 10738        L  BFA24GEN-L026-Saturday-00_006600_L..S01R   Saturday
# 10739        L  BFA24GEN-L026-Saturday-00_007800_L..S01R   Saturday
# 10741        L  BFA24GEN-L026-Saturday-00_009250_L..S01R   Saturday
# 10743        L  BFA24GEN-L026-Saturday-00_011250_L..S01R   Saturday
# ...        ...                                       ...        ...
# 12217        L   BFA24GEN-L049-Weekday-00_144000_L..S01R    Weekday
# 12218        L   BFA24GEN-L049-Weekday-00_145000_L..S01R    Weekday
# 12219        L   BFA24GEN-L049-Weekday-00_146000_L..S01R    Weekday
# 12220        L   BFA24GEN-L049-Weekday-00_147000_L..S01R    Weekday
# 12221        L   BFA24GEN-L049-Weekday-00_148200_L..S01R    Weekday
#
#                 trip_headsign  direction_id shape_id
# 10736  Canarsie-Rockaway Pkwy             1  L..S01R
# 10738  Canarsie-Rockaway Pkwy             1  L..S01R
# 10739  Canarsie-Rockaway Pkwy             1  L..S01R
# 10741  Canarsie-Rockaway Pkwy             1  L..S01R
# 10743  Canarsie-Rockaway Pkwy             1  L..S01R
# ...                       ...           ...      ...
# 12217  Canarsie-Rockaway Pkwy             1  L..S01R
# 12218  Canarsie-Rockaway Pkwy             1  L..S01R
# 12219  Canarsie-Rockaway Pkwy             1  L..S01R
# 12220  Canarsie-Rockaway Pkwy             1  L..S01R
# 12221  Canarsie-Rockaway Pkwy             1  L..S01R
#
# [745 rows x 6 columns]

# %%
ordered_stops("L", 1)
# Out:
# ['L01S',
#  'L02S',
#  'L03S',
#  'L05S',
#  'L06S',
#  'L08S',
#  'L10S',
#  'L11S',
#  'L12S',
#  'L13S',
#  'L14S',
#  'L15S',
#  'L16S',
#  'L17S',
#  'L19S',
#  'L20S',
#  'L21S',
#  'L22S',
#  'L24S',
#  'L25S',
#  'L26S',
#  'L27S',
#  'L28S',
#  'L29S']

# %%
list(G.successors("L06N"))
# Out:
# ['L05N']

# %%
nx.get_node_attributes(G, "stop_name")
# Out:
# {'101': 'Van Cortlandt Park-242 St',
#  '101N': 'Van Cortlandt Park-242 St',
#  '101S': 'Van Cortlandt Park-242 St',
#  '103': '238 St',
#  '103N': '238 St',
#  '103S': '238 St',
#  '104': '231 St',
#  '104N': '231 St',
#  '104S': '231 St',
#  '106': 'Marble Hill-225 St',
#  '106N': 'Marble Hill-225 St',
#  '106S': 'Marble Hill-225 St',
#  '107': '215 St',
#  '107N': '215 St',
#  '107S': '215 St',
#  '108': '207 St',
#  '108N': '207 St',
#  '108S': '207 St',
#  '109': 'Dyckman St',
#  '109N': 'Dyckman St',
#  '109S': 'Dyckman St',
#  '110': '191 St',
#  '110N': '191 St',
#  '110S': '191 St',
#  '111': '181 St',
#  '111N': '181 St',
#  '111S': '181 St',
#  '112': '168 St-Washington Hts',
#  '112N': '168 St-Washington Hts',
#  '112S': '168 St-Washington Hts',
#  '113': '157 St',
#  '113N': '157 St',
#  '113S': '157 St',
#  '114': '145 St',
#  '114N': '145 St',
#  '114S': '145 St',
#  '115': '137 St-City College',
#  '115N': '137 St-City College',
#  '115S': '137 St-City College',
#  '116': '125 St',
#  '116N': '125 St',
#  '116S': '125 St',
#  '117': '116 St-Columbia University',
#  '117N': '116 St-Columbia University',
#  '117S': '116 St-Columbia University',
#  '118': 'Cathedral Pkwy (110 St)',
#  '118N': 'Cathedral Pkwy (110 St)',
#  '118S': 'Cathedral Pkwy (110 St)',
#  '119': '103 St',
#  '119N': '103 St',
#  '119S': '103 St',
#  '120': '96 St',
#  '120N': '96 St',
#  '120S': '96 St',
#  '121': '86 St',
#  '121N': '86 St',
#  '121S': '86 St',
#  '122': '79 St',
#  '122N': '79 St',
#  '122S': '79 St',
#  '123': '72 St',
#  '123N': '72 St',
#  '123S': '72 St',
#  '124': '66 St-Lincoln Center',
#  '124N': '66 St-Lincoln Center',
#  '124S': '66 St-Lincoln Center',
#  '125': '59 St-Columbus Circle',
#  '125N': '59 St-Columbus Circle',
#  '125S': '59 St-Columbus Circle',
#  '126': '50 St',
#  '126N': '50 St',
#  '126S': '50 St',
#  '127': 'Times Sq-42 St',
#  '127N': 'Times Sq-42 St',
#  '127S': 'Times Sq-42 St',
#  '128': '34 St-Penn Station',
#  '128N': '34 St-Penn Station',
#  '128S': '34 St-Penn Station',
#  '129': '28 St',
#  '129N': '28 St',
#  '129S': '28 St',
#  '130': '23 St',
#  '130N': '23 St',
#  '130S': '23 St',
#  '131': '18 St',
#  '131N': '18 St',
#  '131S': '18 St',
#  '132': '14 St',
#  '132N': '14 St',
#  '132S': '14 St',
#  '133': 'Christopher St-Stonewall',
#  '133N': 'Christopher St-Stonewall',
#  '133S': 'Christopher St-Stonewall',
#  '134': 'Houston St',
#  '134N': 'Houston St',
#  '134S': 'Houston St',
#  '135': 'Canal St',
#  '135N': 'Canal St',
#  '135S': 'Canal St',
#  '136': 'Franklin St',
#  '136N': 'Franklin St',
#  '136S': 'Franklin St',
#  '137': 'Chambers St',
#  '137N': 'Chambers St',
#  '137S': 'Chambers St',
#  '138': 'WTC Cortlandt',
#  '138N': 'WTC Cortlandt',
#  '138S': 'WTC Cortlandt',
#  '139': 'Rector St',
#  '139N': 'Rector St',
#  '139S': 'Rector St',
#  '140': 'South Ferry Loop',
#  '140N': 'South Ferry Loop',
#  '140S': 'South Ferry Loop',
#  '142': 'South Ferry',
#  '142N': 'South Ferry',
#  '142S': 'South Ferry',
#  '201': 'Wakefield-241 St',
#  '201N': 'Wakefield-241 St',
#  '201S': 'Wakefield-241 St',
#  '204': 'Nereid Av',
#  '204N': 'Nereid Av',
#  '204S': 'Nereid Av',
#  '205': '233 St',
#  '205N': '233 St',
#  '205S': '233 St',
#  '206': '225 St',
#  '206N': '225 St',
#  '206S': '225 St',
#  '207': '219 St',
#  '207N': '219 St',
#  '207S': '219 St',
#  '208': 'Gun Hill Rd',
#  '208N': 'Gun Hill Rd',
#  '208S': 'Gun Hill Rd',
#  '209': 'Burke Av',
#  '209N': 'Burke Av',
#  '209S': 'Burke Av',
#  '210': 'Allerton Av',
#  '210N': 'Allerton Av',
#  '210S': 'Allerton Av',
#  '211': 'Pelham Pkwy',
#  '211N': 'Pelham Pkwy',
#  '211S': 'Pelham Pkwy',
#  '212': 'Bronx Park East',
#  '212N': 'Bronx Park East',
#  '212S': 'Bronx Park East',
#  '213': 'E 180 St',
#  '213N': 'E 180 St',
#  '213S': 'E 180 St',
#  '214': 'West Farms Sq-E Tremont Av',
#  '214N': 'West Farms Sq-E Tremont Av',
#  '214S': 'West Farms Sq-E Tremont Av',
#  '215': '174 St',
#  '215N': '174 St',
#  '215S': '174 St',
#  '216': 'Freeman St',
#  '216N': 'Freeman St',
#  '216S': 'Freeman St',
#  '217': 'Simpson St',
#  '217N': 'Simpson St',
#  '217S': 'Simpson St',
#  '218': 'Intervale Av',
#  '218N': 'Intervale Av',
#  '218S': 'Intervale Av',
#  '219': 'Prospect Av',
#  '219N': 'Prospect Av',
#  '219S': 'Prospect Av',
#  '220': 'Jackson Av',
#  '220N': 'Jackson Av',
#  '220S': 'Jackson Av',
#  '221': '3 Av-149 St',
#  '221N': '3 Av-149 St',
#  '221S': '3 Av-149 St',
#  '222': '149 St-Grand Concourse',
#  '222N': '149 St-Grand Concourse',
#  '222S': '149 St-Grand Concourse',
#  '224': '135 St',
#  '224N': '135 St',
#  '224S': '135 St',
#  '225': '125 St',
#  '225N': '125 St',
#  '225S': '125 St',
#  '226': '116 St',
#  '226N': '116 St',
#  '226S': '116 St',
#  '227': 'Central Park North (110 St)',
#  '227N': 'Central Park North (110 St)',
#  '227S': 'Central Park North (110 St)',
#  '228': 'Park Place',
#  '228N': 'Park Place',
#  '228S': 'Park Place',
#  '229': 'Fulton St',
#  '229N': 'Fulton St',
#  '229S': 'Fulton St',
#  '230': 'Wall St',
#  '230N': 'Wall St',
#  '230S': 'Wall St',
#  '231': 'Clark St',
#  '231N': 'Clark St',
#  '231S': 'Clark St',
#  '232': 'Borough Hall',
#  '232N': 'Borough Hall',
#  '232S': 'Borough Hall',
#  '233': 'Hoyt St',
#  '233N': 'Hoyt St',
#  '233S': 'Hoyt St',
#  '234': 'Nevins St',
#  '234N': 'Nevins St',
#  '234S': 'Nevins St',
#  '235': 'Atlantic Av-Barclays Ctr',
#  '235N': 'Atlantic Av-Barclays Ctr',
#  '235S': 'Atlantic Av-Barclays Ctr',
#  '236': 'Bergen St',
#  '236N': 'Bergen St',
#  '236S': 'Bergen St',
#  '237': 'Grand Army Plaza',
#  '237N': 'Grand Army Plaza',
#  '237S': 'Grand Army Plaza',
#  '238': 'Eastern Pkwy-Brooklyn Museum',
#  '238N': 'Eastern Pkwy-Brooklyn Museum',
#  '238S': 'Eastern Pkwy-Brooklyn Museum',
#  '239': 'Franklin Av-Medgar Evers College',
#  '239N': 'Franklin Av-Medgar Evers College',
#  '239S': 'Franklin Av-Medgar Evers College',
#  '241': 'President St-Medgar Evers College',
#  '241N': 'President St-Medgar Evers College',
#  '241S': 'President St-Medgar Evers College',
#  '242': 'Sterling St',
#  '242N': 'Sterling St',
#  '242S': 'Sterling St',
#  '243': 'Winthrop St',
#  '243N': 'Winthrop St',
#  '243S': 'Winthrop St',
#  '244': 'Church Av',
#  '244N': 'Church Av',
#  '244S': 'Church Av',
#  '245': 'Beverly Rd',
#  '245N': 'Beverly Rd',
#  '245S': 'Beverly Rd',
#  '246': 'Newkirk Av-Little Haiti',
#  '246N': 'Newkirk Av-Little Haiti',
#  '246S': 'Newkirk Av-Little Haiti',
#  '247': 'Flatbush Av-Brooklyn College',
#  '247N': 'Flatbush Av-Brooklyn College',
#  '247S': 'Flatbush Av-Brooklyn College',
#  '248': 'Nostrand Av',
#  '248N': 'Nostrand Av',
#  '248S': 'Nostrand Av',
#  '249': 'Kingston Av',
#  '249N': 'Kingston Av',
#  '249S': 'Kingston Av',
#  '250': 'Crown Hts-Utica Av',
#  '250N': 'Crown Hts-Utica Av',
#  '250S': 'Crown Hts-Utica Av',
#  '251': 'Sutter Av-Rutland Rd',
#  '251N': 'Sutter Av-Rutland Rd',
#  '251S': 'Sutter Av-Rutland Rd',
#  '252': 'Saratoga Av',
#  '252N': 'Saratoga Av',
#  '252S': 'Saratoga Av',
#  '253': 'Rockaway Av',
#  '253N': 'Rockaway Av',
#  '253S': 'Rockaway Av',
#  '254': 'Junius St',
#  '254N': 'Junius St',
#  '254S': 'Junius St',
#  '255': 'Pennsylvania Av',
#  '255N': 'Pennsylvania Av',
#  '255S': 'Pennsylvania Av',
#  '256': 'Van Siclen Av',
#  '256N': 'Van Siclen Av',
#  '256S': 'Van Siclen Av',
#  '257': 'New Lots Av',
#  '257N': 'New Lots Av',
#  '257S': 'New Lots Av',
#  '301': 'Harlem-148 St',
#  '301N': 'Harlem-148 St',
#  '301S': 'Harlem-148 St',
#  '302': '145 St',
#  '302N': '145 St',
#  '302S': '145 St',
#  '401': 'Woodlawn',
#  '401N': 'Woodlawn',
#  '401S': 'Woodlawn',
#  '402': 'Mosholu Pkwy',
#  '402N': 'Mosholu Pkwy',
#  '402S': 'Mosholu Pkwy',
#  '405': 'Bedford Park Blvd-Lehman College',
#  '405N': 'Bedford Park Blvd-Lehman College',
#  '405S': 'Bedford Park Blvd-Lehman College',
#  '406': 'Kingsbridge Rd',
#  '406N': 'Kingsbridge Rd',
#  '406S': 'Kingsbridge Rd',
#  '407': 'Fordham Rd',
#  '407N': 'Fordham Rd',
#  '407S': 'Fordham Rd',
#  '408': '183 St',
#  '408N': '183 St',
#  '408S': '183 St',
#  '409': 'Burnside Av',
#  '409N': 'Burnside Av',
#  '409S': 'Burnside Av',
#  '410': '176 St',
#  '410N': '176 St',
#  '410S': '176 St',
#  '411': 'Mt Eden Av',
#  '411N': 'Mt Eden Av',
#  '411S': 'Mt Eden Av',
#  '412': '170 St',
#  '412N': '170 St',
#  '412S': '170 St',
#  '413': '167 St',
#  '413N': '167 St',
#  '413S': '167 St',
#  '414': '161 St-Yankee Stadium',
#  '414N': '161 St-Yankee Stadium',
#  '414S': '161 St-Yankee Stadium',
#  '415': '149 St-Grand Concourse',
#  '415N': '149 St-Grand Concourse',
#  '415S': '149 St-Grand Concourse',
#  '416': '138 St-Grand Concourse',
#  '416N': '138 St-Grand Concourse',
#  '416S': '138 St-Grand Concourse',
#  '418': 'Fulton St',
#  '418N': 'Fulton St',
#  '418S': 'Fulton St',
#  '419': 'Wall St',
#  '419N': 'Wall St',
#  '419S': 'Wall St',
#  '420': 'Bowling Green',
#  '420N': 'Bowling Green',
#  '420S': 'Bowling Green',
#  '423': 'Borough Hall',
#  '423N': 'Borough Hall',
#  '423S': 'Borough Hall',
#  '501': 'Eastchester-Dyre Av',
#  '501N': 'Eastchester-Dyre Av',
#  '501S': 'Eastchester-Dyre Av',
#  '502': 'Baychester Av',
#  '502N': 'Baychester Av',
#  '502S': 'Baychester Av',
#  '503': 'Gun Hill Rd',
#  '503N': 'Gun Hill Rd',
#  '503S': 'Gun Hill Rd',
#  '504': 'Pelham Pkwy',
#  '504N': 'Pelham Pkwy',
#  '504S': 'Pelham Pkwy',
#  '505': 'Morris Park',
#  '505N': 'Morris Park',
#  '505S': 'Morris Park',
#  '601': 'Pelham Bay Park',
#  '601N': 'Pelham Bay Park',
#  '601S': 'Pelham Bay Park',
#  '602': 'Buhre Av',
#  '602N': 'Buhre Av',
#  '602S': 'Buhre Av',
#  '603': 'Middletown Rd',
#  '603N': 'Middletown Rd',
#  '603S': 'Middletown Rd',
#  '604': 'Westchester Sq-E Tremont Av',
#  '604N': 'Westchester Sq-E Tremont Av',
#  '604S': 'Westchester Sq-E Tremont Av',
#  '606': 'Zerega Av',
#  '606N': 'Zerega Av',
#  '606S': 'Zerega Av',
#  '607': 'Castle Hill Av',
#  '607N': 'Castle Hill Av',
#  '607S': 'Castle Hill Av',
#  '608': 'Parkchester',
#  '608N': 'Parkchester',
#  '608S': 'Parkchester',
#  '609': 'St Lawrence Av',
#  '609N': 'St Lawrence Av',
#  '609S': 'St Lawrence Av',
#  '610': 'Morrison Av-Soundview',
#  '610N': 'Morrison Av-Soundview',
#  '610S': 'Morrison Av-Soundview',
#  '611': 'Elder Av',
#  '611N': 'Elder Av',
#  '611S': 'Elder Av',
#  '612': 'Whitlock Av',
#  '612N': 'Whitlock Av',
#  '612S': 'Whitlock Av',
#  '613': 'Hunts Point Av',
#  '613N': 'Hunts Point Av',
#  '613S': 'Hunts Point Av',
#  '614': 'Longwood Av',
#  '614N': 'Longwood Av',
#  '614S': 'Longwood Av',
#  '615': 'E 149 St',
#  '615N': 'E 149 St',
#  '615S': 'E 149 St',
#  '616': "E 143 St-St Mary's St",
#  '616N': "E 143 St-St Mary's St",
#  '616S': "E 143 St-St Mary's St",
#  '617': 'Cypress Av',
#  '617N': 'Cypress Av',
#  '617S': 'Cypress Av',
#  '618': 'Brook Av',
#  '618N': 'Brook Av',
#  '618S': 'Brook Av',
#  '619': '3 Av-138 St',
#  '619N': '3 Av-138 St',
#  '619S': '3 Av-138 St',
#  '621': '125 St',
#  '621N': '125 St',
#  '621S': '125 St',
#  '622': '116 St',
#  '622N': '116 St',
#  '622S': '116 St',
#  '623': '110 St',
#  '623N': '110 St',
#  '623S': '110 St',
#  '624': '103 St',
#  '624N': '103 St',
#  '624S': '103 St',
#  '625': '96 St',
#  '625N': '96 St',
#  '625S': '96 St',
#  '626': '86 St',
#  '626N': '86 St',
#  '626S': '86 St',
#  '627': '77 St',
#  '627N': '77 St',
#  '627S': '77 St',
#  '628': '68 St-Hunter College',
#  '628N': '68 St-Hunter College',
#  '628S': '68 St-Hunter College',
#  '629': '59 St',
#  '629N': '59 St',
#  '629S': '59 St',
#  '630': '51 St',
#  '630N': '51 St',
#  '630S': '51 St',
#  '631': 'Grand Central-42 St',
#  '631N': 'Grand Central-42 St',
#  '631S': 'Grand Central-42 St',
#  '632': '33 St',
#  '632N': '33 St',
#  '632S': '33 St',
#  '633': '28 St',
#  '633N': '28 St',
#  '633S': '28 St',
#  '634': '23 St',
#  '634N': '23 St',
#  '634S': '23 St',
#  '635': '14 St-Union Sq',
#  '635N': '14 St-Union Sq',
#  '635S': '14 St-Union Sq',
#  '636': 'Astor Pl',
#  '636N': 'Astor Pl',
#  '636S': 'Astor Pl',
#  '637': 'Bleecker St',
#  '637N': 'Bleecker St',
#  '637S': 'Bleecker St',
#  '638': 'Spring St',
#  '638N': 'Spring St',
#  '638S': 'Spring St',
#  '639': 'Canal St',
#  '639N': 'Canal St',
#  '639S': 'Canal St',
#  '640': 'Brooklyn Bridge-City Hall',
#  '640N': 'Brooklyn Bridge-City Hall',
#  '640S': 'Brooklyn Bridge-City Hall',
#  '701': 'Flushing-Main St',
#  '701N': 'Flushing-Main St',
#  '701S': 'Flushing-Main St',
#  '702': 'Mets-Willets Point',
#  '702N': 'Mets-Willets Point',
#  '702S': 'Mets-Willets Point',
#  '705': '111 St',
#  '705N': '111 St',
#  '705S': '111 St',
#  '706': '103 St-Corona Plaza',
#  '706N': '103 St-Corona Plaza',
#  '706S': '103 St-Corona Plaza',
#  '707': 'Junction Blvd',
#  '707N': 'Junction Blvd',
#  '707S': 'Junction Blvd',
#  '708': '90 St-Elmhurst Av',
#  '708N': '90 St-Elmhurst Av',
#  '708S': '90 St-Elmhurst Av',
#  '709': '82 St-Jackson Hts',
#  '709N': '82 St-Jackson Hts',
#  '709S': '82 St-Jackson Hts',
#  '710': '74 St-Broadway',
#  '710N': '74 St-Broadway',
#  '710S': '74 St-Broadway',
#  '711': '69 St',
#  '711N': '69 St',
#  '711S': '69 St',
#  '712': '61 St-Woodside',
#  '712N': '61 St-Woodside',
#  '712S': '61 St-Woodside',
#  '713': '52 St',
#  '713N': '52 St',
#  '713S': '52 St',
#  '714': '46 St-Bliss St',
#  '714N': '46 St-Bliss St',
#  '714S': '46 St-Bliss St',
#  '715': '40 St-Lowery St',
#  '715N': '40 St-Lowery St',
#  '715S': '40 St-Lowery St',
#  '716': '33 St-Rawson St',
#  '716N': '33 St-Rawson St',
#  '716S': '33 St-Rawson St',
#  '718': 'Queensboro Plaza',
#  '718N': 'Queensboro Plaza',
#  '718S': 'Queensboro Plaza',
#  '719': 'Court Sq',
#  '719N': 'Court Sq',
#  '719S': 'Court Sq',
#  '720': 'Hunters Point Av',
#  '720N': 'Hunters Point Av',
#  '720S': 'Hunters Point Av',
#  '721': 'Vernon Blvd-Jackson Av',
#  '721N': 'Vernon Blvd-Jackson Av',
#  '721S': 'Vernon Blvd-Jackson Av',
#  '723': 'Grand Central-42 St',
#  '723N': 'Grand Central-42 St',
#  '723S': 'Grand Central-42 St',
#  '724': '5 Av',
#  '724N': '5 Av',
#  '724S': '5 Av',
#  '725': 'Times Sq-42 St',
#  '725N': 'Times Sq-42 St',
#  '725S': 'Times Sq-42 St',
#  '726': '34 St-Hudson Yards',
#  '726N': '34 St-Hudson Yards',
#  '726S': '34 St-Hudson Yards',
#  '901': 'Grand Central-42 St',
#  '901N': 'Grand Central-42 St',
#  '901S': 'Grand Central-42 St',
#  '902': 'Times Sq-42 St',
#  '902N': 'Times Sq-42 St',
#  '902S': 'Times Sq-42 St',
#  'A02': 'Inwood-207 St',
#  'A02N': 'Inwood-207 St',
#  'A02S': 'Inwood-207 St',
#  'A03': 'Dyckman St',
#  'A03N': 'Dyckman St',
#  'A03S': 'Dyckman St',
#  'A05': '190 St',
#  'A05N': '190 St',
#  'A05S': '190 St',
#  'A06': '181 St',
#  'A06N': '181 St',
#  'A06S': '181 St',
#  'A07': '175 St',
#  'A07N': '175 St',
#  'A07S': '175 St',
#  'A09': '168 St',
#  'A09N': '168 St',
#  'A09S': '168 St',
#  'A10': '163 St-Amsterdam Av',
#  'A10N': '163 St-Amsterdam Av',
#  'A10S': '163 St-Amsterdam Av',
#  'A11': '155 St',
#  'A11N': '155 St',
#  'A11S': '155 St',
#  'A12': '145 St',
#  'A12N': '145 St',
#  'A12S': '145 St',
#  'A14': '135 St',
#  'A14N': '135 St',
#  'A14S': '135 St',
#  'A15': '125 St',
#  'A15N': '125 St',
#  'A15S': '125 St',
#  'A16': '116 St',
#  'A16N': '116 St',
#  'A16S': '116 St',
#  'A17': 'Cathedral Pkwy (110 St)',
#  'A17N': 'Cathedral Pkwy (110 St)',
#  'A17S': 'Cathedral Pkwy (110 St)',
#  'A18': '103 St',
#  'A18N': '103 St',
#  'A18S': '103 St',
#  'A19': '96 St',
#  'A19N': '96 St',
#  'A19S': '96 St',
#  'A20': '86 St',
#  'A20N': '86 St',
#  'A20S': '86 St',
#  'A21': '81 St-Museum of Natural History',
#  'A21N': '81 St-Museum of Natural History',
#  'A21S': '81 St-Museum of Natural History',
#  'A22': '72 St',
#  'A22N': '72 St',
#  'A22S': '72 St',
#  'A24': '59 St-Columbus Circle',
#  'A24N': '59 St-Columbus Circle',
#  'A24S': '59 St-Columbus Circle',
#  'A25': '50 St',
#  'A25N': '50 St',
#  'A25S': '50 St',
#  'A27': '42 St-Port Authority Bus Terminal',
#  'A27N': '42 St-Port Authority Bus Terminal',
#  'A27S': '42 St-Port Authority Bus Terminal',
#  'A28': '34 St-Penn Station',
#  'A28N': '34 St-Penn Station',
#  'A28S': '34 St-Penn Station',
#  'A30': '23 St',
#  'A30N': '23 St',
#  'A30S': '23 St',
#  'A31': '14 St',
#  'A31N': '14 St',
#  'A31S': '14 St',
#  'A32': 'W 4 St-Wash Sq',
#  'A32N': 'W 4 St-Wash Sq',
#  'A32S': 'W 4 St-Wash Sq',
#  'A33': 'Spring St',
#  'A33N': 'Spring St',
#  'A33S': 'Spring St',
#  'A34': 'Canal St',
#  'A34N': 'Canal St',
#  'A34S': 'Canal St',
#  'A36': 'Chambers St',
#  'A36N': 'Chambers St',
#  'A36S': 'Chambers St',
#  'A38': 'Fulton St',
#  'A38N': 'Fulton St',
#  'A38S': 'Fulton St',
#  'A40': 'High St',
#  'A40N': 'High St',
#  'A40S': 'High St',
#  'A41': 'Jay St-MetroTech',
#  'A41N': 'Jay St-MetroTech',
#  'A41S': 'Jay St-MetroTech',
#  'A42': 'Hoyt-Schermerhorn Sts',
#  'A42N': 'Hoyt-Schermerhorn Sts',
#  'A42S': 'Hoyt-Schermerhorn Sts',
#  'A43': 'Lafayette Av',
#  'A43N': 'Lafayette Av',
#  'A43S': 'Lafayette Av',
#  'A44': 'Clinton-Washington Avs',
#  'A44N': 'Clinton-Washington Avs',
#  'A44S': 'Clinton-Washington Avs',
#  'A45': 'Franklin Av',
#  'A45N': 'Franklin Av',
#  'A45S': 'Franklin Av',
#  'A46': 'Nostrand Av',
#  'A46N': 'Nostrand Av',
#  'A46S': 'Nostrand Av',
#  'A47': 'Kingston-Throop Avs',
#  'A47N': 'Kingston-Throop Avs',
#  'A47S': 'Kingston-Throop Avs',
#  'A48': 'Utica Av',
#  'A48N': 'Utica Av',
#  'A48S': 'Utica Av',
#  'A49': 'Ralph Av',
#  'A49N': 'Ralph Av',
#  'A49S': 'Ralph Av',
#  'A50': 'Rockaway Av',
#  'A50N': 'Rockaway Av',
#  'A50S': 'Rockaway Av',
#  'A51': 'Broadway Junction',
#  'A51N': 'Broadway Junction',
#  'A51S': 'Broadway Junction',
#  'A52': 'Liberty Av',
#  'A52N': 'Liberty Av',
#  'A52S': 'Liberty Av',
#  'A53': 'Van Siclen Av',
#  'A53N': 'Van Siclen Av',
#  'A53S': 'Van Siclen Av',
#  'A54': 'Shepherd Av',
#  'A54N': 'Shepherd Av',
#  'A54S': 'Shepherd Av',
#  'A55': 'Euclid Av',
#  'A55N': 'Euclid Av',
#  'A55S': 'Euclid Av',
#  'A57': 'Grant Av',
#  'A57N': 'Grant Av',
#  'A57S': 'Grant Av',
#  'A59': '80 St',
#  'A59N': '80 St',
#  'A59S': '80 St',
#  'A60': '88 St',
#  'A60N': '88 St',
#  'A60S': '88 St',
#  'A61': 'Rockaway Blvd',
#  'A61N': 'Rockaway Blvd',
#  'A61S': 'Rockaway Blvd',
#  'A63': '104 St',
#  'A63N': '104 St',
#  'A63S': '104 St',
#  'A64': '111 St',
#  'A64N': '111 St',
#  'A64S': '111 St',
#  'A65': 'Ozone Park-Lefferts Blvd',
#  'A65N': 'Ozone Park-Lefferts Blvd',
#  'A65S': 'Ozone Park-Lefferts Blvd',
#  'B04': '21 St-Queensbridge',
#  'B04N': '21 St-Queensbridge',
#  'B04S': '21 St-Queensbridge',
#  'B06': 'Roosevelt Island',
#  'B06N': 'Roosevelt Island',
#  'B06S': 'Roosevelt Island',
#  'B08': 'Lexington Av/63 St',
#  'B08N': 'Lexington Av/63 St',
#  'B08S': 'Lexington Av/63 St',
#  'B10': '57 St',
#  'B10N': '57 St',
#  'B10S': '57 St',
#  'B12': '9 Av',
#  'B12N': '9 Av',
#  'B12S': '9 Av',
#  'B13': 'Fort Hamilton Pkwy',
#  'B13N': 'Fort Hamilton Pkwy',
#  'B13S': 'Fort Hamilton Pkwy',
#  'B14': '50 St',
#  'B14N': '50 St',
#  'B14S': '50 St',
#  'B15': '55 St',
#  'B15N': '55 St',
#  'B15S': '55 St',
#  'B16': '62 St',
#  'B16N': '62 St',
#  'B16S': '62 St',
#  'B17': '71 St',
#  'B17N': '71 St',
#  'B17S': '71 St',
#  'B18': '79 St',
#  'B18N': '79 St',
#  'B18S': '79 St',
#  'B19': '18 Av',
#  'B19N': '18 Av',
#  'B19S': '18 Av',
#  'B20': '20 Av',
#  'B20N': '20 Av',
#  'B20S': '20 Av',
#  'B21': 'Bay Pkwy',
#  'B21N': 'Bay Pkwy',
#  'B21S': 'Bay Pkwy',
#  'B22': '25 Av',
#  'B22N': '25 Av',
#  'B22S': '25 Av',
#  'B23': 'Bay 50 St',
#  'B23N': 'Bay 50 St',
#  'B23S': 'Bay 50 St',
#  'D01': 'Norwood-205 St',
#  'D01N': 'Norwood-205 St',
#  'D01S': 'Norwood-205 St',
#  'D03': 'Bedford Park Blvd',
#  'D03N': 'Bedford Park Blvd',
#  'D03S': 'Bedford Park Blvd',
#  'D04': 'Kingsbridge Rd',
#  'D04N': 'Kingsbridge Rd',
#  'D04S': 'Kingsbridge Rd',
#  'D05': 'Fordham Rd',
#  'D05N': 'Fordham Rd',
#  'D05S': 'Fordham Rd',
#  'D06': '182-183 Sts',
#  'D06N': '182-183 Sts',
#  'D06S': '182-183 Sts',
#  'D07': 'Tremont Av',
#  'D07N': 'Tremont Av',
#  'D07S': 'Tremont Av',
#  'D08': '174-175 Sts',
#  'D08N': '174-175 Sts',
#  'D08S': '174-175 Sts',
#  'D09': '170 St',
#  'D09N': '170 St',
#  'D09S': '170 St',
#  'D10': '167 St',
#  'D10N': '167 St',
#  'D10S': '167 St',
#  'D11': '161 St-Yankee Stadium',
#  'D11N': '161 St-Yankee Stadium',
#  'D11S': '161 St-Yankee Stadium',
#  'D12': '155 St',
#  'D12N': '155 St',
#  'D12S': '155 St',
#  'D13': '145 St',
#  'D13N': '145 St',
#  'D13S': '145 St',
#  'D14': '7 Av',
#  'D14N': '7 Av',
#  'D14S': '7 Av',
#  'D15': '47-50 Sts-Rockefeller Ctr',
#  'D15N': '47-50 Sts-Rockefeller Ctr',
#  'D15S': '47-50 Sts-Rockefeller Ctr',
#  'D16': '42 St-Bryant Pk',
#  'D16N': '42 St-Bryant Pk',
#  'D16S': '42 St-Bryant Pk',
#  'D17': '34 St-Herald Sq',
#  'D17N': '34 St-Herald Sq',
#  'D17S': '34 St-Herald Sq',
#  'D18': '23 St',
#  'D18N': '23 St',
#  'D18S': '23 St',
#  'D19': '14 St',
#  'D19N': '14 St',
#  'D19S': '14 St',
#  'D20': 'W 4 St-Wash Sq',
#  'D20N': 'W 4 St-Wash Sq',
#  'D20S': 'W 4 St-Wash Sq',
#  'D21': 'Broadway-Lafayette St',
#  'D21N': 'Broadway-Lafayette St',
#  'D21S': 'Broadway-Lafayette St',
#  'D22': 'Grand St',
#  'D22N': 'Grand St',
#  'D22S': 'Grand St',
#  'D24': 'Atlantic Av-Barclays Ctr',
#  'D24N': 'Atlantic Av-Barclays Ctr',
#  'D24S': 'Atlantic Av-Barclays Ctr',
#  'D25': '7 Av',
#  'D25N': '7 Av',
#  'D25S': '7 Av',
#  'D26': 'Prospect Park',
#  'D26N': 'Prospect Park',
#  'D26S': 'Prospect Park',
#  'D27': 'Parkside Av',
#  'D27N': 'Parkside Av',
#  'D27S': 'Parkside Av',
#  'D28': 'Church Av',
#  'D28N': 'Church Av',
#  'D28S': 'Church Av',
#  'D29': 'Beverley Rd',
#  'D29N': 'Beverley Rd',
#  'D29S': 'Beverley Rd',
#  'D30': 'Cortelyou Rd',
#  'D30N': 'Cortelyou Rd',
#  'D30S': 'Cortelyou Rd',
#  'D31': 'Newkirk Plaza',
#  'D31N': 'Newkirk Plaza',
#  'D31S': 'Newkirk Plaza',
#  'D32': 'Avenue H',
#  'D32N': 'Avenue H',
#  'D32S': 'Avenue H',
#  'D33': 'Avenue J',
#  'D33N': 'Avenue J',
#  'D33S': 'Avenue J',
#  'D34': 'Avenue M',
#  'D34N': 'Avenue M',
#  'D34S': 'Avenue M',
#  'D35': 'Kings Hwy',
#  'D35N': 'Kings Hwy',
#  'D35S': 'Kings Hwy',
#  'D37': 'Avenue U',
#  'D37N': 'Avenue U',
#  'D37S': 'Avenue U',
#  'D38': 'Neck Rd',
#  'D38N': 'Neck Rd',
#  'D38S': 'Neck Rd',
#  'D39': 'Sheepshead Bay',
#  'D39N': 'Sheepshead Bay',
#  'D39S': 'Sheepshead Bay',
#  'D40': 'Brighton Beach',
#  'D40N': 'Brighton Beach',
#  'D40S': 'Brighton Beach',
#  'D41': 'Ocean Pkwy',
#  'D41N': 'Ocean Pkwy',
#  'D41S': 'Ocean Pkwy',
#  'D42': 'W 8 St-NY Aquarium',
#  'D42N': 'W 8 St-NY Aquarium',
#  'D42S': 'W 8 St-NY Aquarium',
#  'D43': 'Coney Island-Stillwell Av',
#  'D43N': 'Coney Island-Stillwell Av',
#  'D43S': 'Coney Island-Stillwell Av',
#  'E01': 'World Trade Center',
#  'E01N': 'World Trade Center',
#  'E01S': 'World Trade Center',
#  'F01': 'Jamaica-179 St',
#  'F01N': 'Jamaica-179 St',
#  'F01S': 'Jamaica-179 St',
#  'F02': '169 St',
#  'F02N': '169 St',
#  'F02S': '169 St',
#  'F03': 'Parsons Blvd',
#  'F03N': 'Parsons Blvd',
#  'F03S': 'Parsons Blvd',
#  'F04': 'Sutphin Blvd',
#  'F04N': 'Sutphin Blvd',
#  'F04S': 'Sutphin Blvd',
#  'F05': 'Briarwood',
#  'F05N': 'Briarwood',
#  'F05S': 'Briarwood',
#  'F06': 'Kew Gardens-Union Tpke',
#  'F06N': 'Kew Gardens-Union Tpke',
#  'F06S': 'Kew Gardens-Union Tpke',
#  'F07': '75 Av',
#  'F07N': '75 Av',
#  'F07S': '75 Av',
#  'F09': 'Court Sq-23 St',
#  'F09N': 'Court Sq-23 St',
#  'F09S': 'Court Sq-23 St',
#  'F11': 'Lexington Av/53 St',
#  'F11N': 'Lexington Av/53 St',
#  'F11S': 'Lexington Av/53 St',
#  'F12': '5 Av/53 St',
#  'F12N': '5 Av/53 St',
#  'F12S': '5 Av/53 St',
#  'F14': '2 Av',
#  'F14N': '2 Av',
#  'F14S': '2 Av',
#  'F15': 'Delancey St-Essex St',
#  'F15N': 'Delancey St-Essex St',
#  'F15S': 'Delancey St-Essex St',
#  'F16': 'East Broadway',
#  'F16N': 'East Broadway',
#  'F16S': 'East Broadway',
#  'F18': 'York St',
#  'F18N': 'York St',
#  'F18S': 'York St',
#  'F20': 'Bergen St',
#  'F20N': 'Bergen St',
#  'F20S': 'Bergen St',
#  'F21': 'Carroll St',
#  'F21N': 'Carroll St',
#  'F21S': 'Carroll St',
#  'F22': 'Smith-9 Sts',
#  'F22N': 'Smith-9 Sts',
#  'F22S': 'Smith-9 Sts',
#  'F23': '4 Av-9 St',
#  'F23N': '4 Av-9 St',
#  'F23S': '4 Av-9 St',
#  'F24': '7 Av',
#  'F24N': '7 Av',
#  'F24S': '7 Av',
#  'F25': '15 St-Prospect Park',
#  'F25N': '15 St-Prospect Park',
#  'F25S': '15 St-Prospect Park',
#  'F26': 'Fort Hamilton Pkwy',
#  'F26N': 'Fort Hamilton Pkwy',
#  'F26S': 'Fort Hamilton Pkwy',
#  'F27': 'Church Av',
#  'F27N': 'Church Av',
#  'F27S': 'Church Av',
#  'F29': 'Ditmas Av',
#  'F29N': 'Ditmas Av',
#  'F29S': 'Ditmas Av',
#  'F30': '18 Av',
#  'F30N': '18 Av',
#  'F30S': '18 Av',
#  'F31': 'Avenue I',
#  'F31N': 'Avenue I',
#  'F31S': 'Avenue I',
#  'F32': 'Bay Pkwy',
#  'F32N': 'Bay Pkwy',
#  'F32S': 'Bay Pkwy',
#  'F33': 'Avenue N',
#  'F33N': 'Avenue N',
#  'F33S': 'Avenue N',
#  'F34': 'Avenue P',
#  'F34N': 'Avenue P',
#  'F34S': 'Avenue P',
#  'F35': 'Kings Hwy',
#  'F35N': 'Kings Hwy',
#  'F35S': 'Kings Hwy',
#  'F36': 'Avenue U',
#  'F36N': 'Avenue U',
#  'F36S': 'Avenue U',
#  'F38': 'Avenue X',
#  'F38N': 'Avenue X',
#  'F38S': 'Avenue X',
#  'F39': 'Neptune Av',
#  'F39N': 'Neptune Av',
#  'F39S': 'Neptune Av',
#  'G05': 'Jamaica Center-Parsons/Archer',
#  'G05N': 'Jamaica Center-Parsons/Archer',
#  'G05S': 'Jamaica Center-Parsons/Archer',
#  'G06': 'Sutphin Blvd-Archer Av-JFK Airport',
#  'G06N': 'Sutphin Blvd-Archer Av-JFK Airport',
#  'G06S': 'Sutphin Blvd-Archer Av-JFK Airport',
#  'G07': 'Jamaica-Van Wyck',
#  'G07N': 'Jamaica-Van Wyck',
#  'G07S': 'Jamaica-Van Wyck',
#  'G08': 'Forest Hills-71 Av',
#  'G08N': 'Forest Hills-71 Av',
#  'G08S': 'Forest Hills-71 Av',
#  'G09': '67 Av',
#  'G09N': '67 Av',
#  'G09S': '67 Av',
#  'G10': '63 Dr-Rego Park',
#  'G10N': '63 Dr-Rego Park',
#  'G10S': '63 Dr-Rego Park',
#  'G11': 'Woodhaven Blvd',
#  'G11N': 'Woodhaven Blvd',
#  'G11S': 'Woodhaven Blvd',
#  'G12': 'Grand Av-Newtown',
#  'G12N': 'Grand Av-Newtown',
#  'G12S': 'Grand Av-Newtown',
#  'G13': 'Elmhurst Av',
#  'G13N': 'Elmhurst Av',
#  'G13S': 'Elmhurst Av',
#  'G14': 'Jackson Hts-Roosevelt Av',
#  'G14N': 'Jackson Hts-Roosevelt Av',
#  'G14S': 'Jackson Hts-Roosevelt Av',
#  'G15': '65 St',
#  'G15N': '65 St',
#  'G15S': '65 St',
#  'G16': 'Northern Blvd',
#  'G16N': 'Northern Blvd',
#  'G16S': 'Northern Blvd',
#  'G18': '46 St',
#  'G18N': '46 St',
#  'G18S': '46 St',
#  'G19': 'Steinway St',
#  ...}

# %%
names = [G.nodes[s]["stop_name"] for s in ordered_stops("L", 0)]
names
# Out:
# ['Canarsie-Rockaway Pkwy',
#  'East 105 St',
#  'New Lots Av',
#  'Livonia Av',
#  'Sutter Av',
#  'Atlantic Av',
#  'Broadway Junction',
#  'Bushwick Av-Aberdeen St',
#  'Wilson Av',
#  'Halsey St',
#  'Myrtle-Wyckoff Avs',
#  'DeKalb Av',
#  'Jefferson St',
#  'Morgan Av',
#  'Montrose Av',
#  'Grand St',
#  'Graham Av',
#  'Lorimer St',
#  'Bedford Av',
#  '1 Av',
#  '3 Av',
#  '14 St-Union Sq',
#  '6 Av',
#  '8 Av']

# %%
from collections import defaultdict

route_graphs = defaultdict(nx.Graph)
for u, v, data in G.edges(data=True):
    for route in data["route_id"]:            # edge may be served by many lines
        route_graphs[route].add_edge(u, v)

def has_same_line_path(src, dst, route):
    """True iff a train on `route` can carry you from src → dst without transfer."""
    g = route_graphs.get(route)
    return g and nx.has_path(g, src, dst)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 5
#       3 route_graphs = defaultdict(nx.Graph)
#       4 for u, v, data in G.edges(data=True):
# ----> 5     for route in data["route_id"]:            # edge may be served by many lines
#       6         route_graphs[route].add_edge(u, v)
#       8 def has_same_line_path(src, dst, route):
#
# KeyError: 'route_id'

# %%
G.nodes
# Out:
# NodeView(('101', '101N', '101S', '103', '103N', '103S', '104', '104N', '104S', '106', '106N', '106S', '107', '107N', '107S', '108', '108N', '108S', '109', '109N', '109S', '110', '110N', '110S', '111', '111N', '111S', '112', '112N', '112S', '113', '113N', '113S', '114', '114N', '114S', '115', '115N', '115S', '116', '116N', '116S', '117', '117N', '117S', '118', '118N', '118S', '119', '119N', '119S', '120', '120N', '120S', '121', '121N', '121S', '122', '122N', '122S', '123', '123N', '123S', '124', '124N', '124S', '125', '125N', '125S', '126', '126N', '126S', '127', '127N', '127S', '128', '128N', '128S', '129', '129N', '129S', '130', '130N', '130S', '131', '131N', '131S', '132', '132N', '132S', '133', '133N', '133S', '134', '134N', '134S', '135', '135N', '135S', '136', '136N', '136S', '137', '137N', '137S', '138', '138N', '138S', '139', '139N', '139S', '140', '140N', '140S', '142', '142N', '142S', '201', '201N', '201S', '204', '204N', '204S', '205', '205N', '205S', '206', '206N', '206S', '207', '207N', '207S', '208', '208N', '208S', '209', '209N', '209S', '210', '210N', '210S', '211', '211N', '211S', '212', '212N', '212S', '213', '213N', '213S', '214', '214N', '214S', '215', '215N', '215S', '216', '216N', '216S', '217', '217N', '217S', '218', '218N', '218S', '219', '219N', '219S', '220', '220N', '220S', '221', '221N', '221S', '222', '222N', '222S', '224', '224N', '224S', '225', '225N', '225S', '226', '226N', '226S', '227', '227N', '227S', '228', '228N', '228S', '229', '229N', '229S', '230', '230N', '230S', '231', '231N', '231S', '232', '232N', '232S', '233', '233N', '233S', '234', '234N', '234S', '235', '235N', '235S', '236', '236N', '236S', '237', '237N', '237S', '238', '238N', '238S', '239', '239N', '239S', '241', '241N', '241S', '242', '242N', '242S', '243', '243N', '243S', '244', '244N', '244S', '245', '245N', '245S', '246', '246N', '246S', '247', '247N', '247S', '248', '248N', '248S', '249', '249N', '249S', '250', '250N', '250S', '251', '251N', '251S', '252', '252N', '252S', '253', '253N', '253S', '254', '254N', '254S', '255', '255N', '255S', '256', '256N', '256S', '257', '257N', '257S', '301', '301N', '301S', '302', '302N', '302S', '401', '401N', '401S', '402', '402N', '402S', '405', '405N', '405S', '406', '406N', '406S', '407', '407N', '407S', '408', '408N', '408S', '409', '409N', '409S', '410', '410N', '410S', '411', '411N', '411S', '412', '412N', '412S', '413', '413N', '413S', '414', '414N', '414S', '415', '415N', '415S', '416', '416N', '416S', '418', '418N', '418S', '419', '419N', '419S', '420', '420N', '420S', '423', '423N', '423S', '501', '501N', '501S', '502', '502N', '502S', '503', '503N', '503S', '504', '504N', '504S', '505', '505N', '505S', '601', '601N', '601S', '602', '602N', '602S', '603', '603N', '603S', '604', '604N', '604S', '606', '606N', '606S', '607', '607N', '607S', '608', '608N', '608S', '609', '609N', '609S', '610', '610N', '610S', '611', '611N', '611S', '612', '612N', '612S', '613', '613N', '613S', '614', '614N', '614S', '615', '615N', '615S', '616', '616N', '616S', '617', '617N', '617S', '618', '618N', '618S', '619', '619N', '619S', '621', '621N', '621S', '622', '622N', '622S', '623', '623N', '623S', '624', '624N', '624S', '625', '625N', '625S', '626', '626N', '626S', '627', '627N', '627S', '628', '628N', '628S', '629', '629N', '629S', '630', '630N', '630S', '631', '631N', '631S', '632', '632N', '632S', '633', '633N', '633S', '634', '634N', '634S', '635', '635N', '635S', '636', '636N', '636S', '637', '637N', '637S', '638', '638N', '638S', '639', '639N', '639S', '640', '640N', '640S', '701', '701N', '701S', '702', '702N', '702S', '705', '705N', '705S', '706', '706N', '706S', '707', '707N', '707S', '708', '708N', '708S', '709', '709N', '709S', '710', '710N', '710S', '711', '711N', '711S', '712', '712N', '712S', '713', '713N', '713S', '714', '714N', '714S', '715', '715N', '715S', '716', '716N', '716S', '718', '718N', '718S', '719', '719N', '719S', '720', '720N', '720S', '721', '721N', '721S', '723', '723 ...

# %%
nx.shortest_path(G, 'L01S', '128')
# Out:
# ---------------------------------------------------------------------------
# NetworkXNoPath                            Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 nx.shortest_path(G, 'L01S', '128')
#
# File <class 'networkx.utils.decorators.argmap'> compilation 4:3, in argmap_shortest_path_1(G, source, target, weight, method, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~/Desktop/MTA-Real-time-API/venv/lib/python3.12/site-packages/networkx/utils/backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~/Desktop/MTA-Real-time-API/venv/lib/python3.12/site-packages/networkx/algorithms/shortest_paths/generic.py:183, in shortest_path(G, source, target, weight, method)
#     180 else:
#     181     # Find shortest source-target path.
#     182     if method == "unweighted":
# --> 183         paths = nx.bidirectional_shortest_path(G, source, target)
#     184     elif method == "dijkstra":
#     185         _, paths = nx.bidirectional_dijkstra(G, source, target, weight)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 8:3, in argmap_bidirectional_shortest_path_5(G, source, target, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~/Desktop/MTA-Real-time-API/venv/lib/python3.12/site-packages/networkx/utils/backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~/Desktop/MTA-Real-time-API/venv/lib/python3.12/site-packages/networkx/algorithms/shortest_paths/unweighted.py:250, in bidirectional_shortest_path(G, source, target)
#     247     raise nx.NodeNotFound(f"Target {target} is not in G")
#     249 # call helper to do the real work
# --> 250 results = _bidirectional_pred_succ(G, source, target)
#     251 pred, succ, w = results
#     253 # build path from pred+w+succ
#
# File ~/Desktop/MTA-Real-time-API/venv/lib/python3.12/site-packages/networkx/algorithms/shortest_paths/unweighted.py:318, in _bidirectional_pred_succ(G, source, target)
#     315                 if w in pred:  # found path
#     316                     return pred, succ, w
# --> 318 raise nx.NetworkXNoPath(f"No path between {source} and {target}.")
#
# NetworkXNoPath: No path between L01S and 128.

# %%
lookup_sid
# Out:
# {'Van Cortlandt Park-242 St': '101S',
#  '238 St': '103S',
#  '231 St': '104S',
#  'Marble Hill-225 St': '106S',
#  '215 St': '107S',
#  '207 St': '108S',
#  'Dyckman St': 'A03S',
#  '191 St': '110S',
#  '181 St': 'A06S',
#  '168 St-Washington Hts': '112S',
#  '157 St': '113S',
#  '145 St': 'D13S',
#  '137 St-City College': '115S',
#  '125 St': 'A15S',
#  '116 St-Columbia University': '117S',
#  'Cathedral Pkwy (110 St)': 'A17S',
#  '103 St': 'A18S',
#  '96 St': 'Q05S',
#  '86 St': 'R44S',
#  '79 St': 'B18S',
#  '72 St': 'Q03S',
#  '66 St-Lincoln Center': '124S',
#  '59 St-Columbus Circle': 'A24S',
#  '50 St': 'B14S',
#  'Times Sq-42 St': 'R16S',
#  '34 St-Penn Station': 'A28S',
#  '28 St': 'R18S',
#  '23 St': 'R19S',
#  '18 St': '131S',
#  '14 St': 'D19S',
#  'Christopher St-Stonewall': '133S',
#  'Houston St': '134S',
#  'Canal St': 'R23S',
#  'Franklin St': '136S',
#  'Chambers St': 'M21S',
#  'WTC Cortlandt': '138S',
#  'Rector St': 'R26S',
#  'South Ferry Loop': '140S',
#  'South Ferry': '142S',
#  'Wakefield-241 St': '201S',
#  'Nereid Av': '204S',
#  '233 St': '205S',
#  '225 St': '206S',
#  '219 St': '207S',
#  'Gun Hill Rd': '503S',
#  'Burke Av': '209S',
#  'Allerton Av': '210S',
#  'Pelham Pkwy': '504S',
#  'Bronx Park East': '212S',
#  'E 180 St': '213S',
#  'West Farms Sq-E Tremont Av': '214S',
#  '174 St': '215S',
#  'Freeman St': '216S',
#  'Simpson St': '217S',
#  'Intervale Av': '218S',
#  'Prospect Av': 'R34S',
#  'Jackson Av': '220S',
#  '3 Av-149 St': '221S',
#  '149 St-Grand Concourse': '415S',
#  '135 St': 'A14S',
#  '116 St': 'A16S',
#  'Central Park North (110 St)': '227S',
#  'Park Place': '228S',
#  'Fulton St': 'M22S',
#  'Wall St': '419S',
#  'Clark St': '231S',
#  'Borough Hall': '423S',
#  'Hoyt St': '233S',
#  'Nevins St': '234S',
#  'Atlantic Av-Barclays Ctr': 'R31S',
#  'Bergen St': 'F20S',
#  'Grand Army Plaza': '237S',
#  'Eastern Pkwy-Brooklyn Museum': '238S',
#  'Franklin Av-Medgar Evers College': '239S',
#  'President St-Medgar Evers College': '241S',
#  'Sterling St': '242S',
#  'Winthrop St': '243S',
#  'Church Av': 'F27S',
#  'Beverly Rd': '245S',
#  'Newkirk Av-Little Haiti': '246S',
#  'Flatbush Av-Brooklyn College': '247S',
#  'Nostrand Av': 'A46S',
#  'Kingston Av': '249S',
#  'Crown Hts-Utica Av': '250S',
#  'Sutter Av-Rutland Rd': '251S',
#  'Saratoga Av': '252S',
#  'Rockaway Av': 'A50S',
#  'Junius St': '254S',
#  'Pennsylvania Av': '255S',
#  'Van Siclen Av': 'J23S',
#  'New Lots Av': 'L27S',
#  'Harlem-148 St': '301S',
#  'Woodlawn': '401S',
#  'Mosholu Pkwy': '402S',
#  'Bedford Park Blvd-Lehman College': '405S',
#  'Kingsbridge Rd': 'D04S',
#  'Fordham Rd': 'D05S',
#  '183 St': '408S',
#  'Burnside Av': '409S',
#  '176 St': '410S',
#  'Mt Eden Av': '411S',
#  '170 St': 'D09S',
#  '167 St': 'D10S',
#  '161 St-Yankee Stadium': 'D11S',
#  '138 St-Grand Concourse': '416S',
#  'Bowling Green': '420S',
#  'Eastchester-Dyre Av': '501S',
#  'Baychester Av': '502S',
#  'Morris Park': '505S',
#  'Pelham Bay Park': '601S',
#  'Buhre Av': '602S',
#  'Middletown Rd': '603S',
#  'Westchester Sq-E Tremont Av': '604S',
#  'Zerega Av': '606S',
#  'Castle Hill Av': '607S',
#  'Parkchester': '608S',
#  'St Lawrence Av': '609S',
#  'Morrison Av-Soundview': '610S',
#  'Elder Av': '611S',
#  'Whitlock Av': '612S',
#  'Hunts Point Av': '613S',
#  'Longwood Av': '614S',
#  'E 149 St': '615S',
#  "E 143 St-St Mary's St": '616S',
#  'Cypress Av': '617S',
#  'Brook Av': '618S',
#  '3 Av-138 St': '619S',
#  '110 St': '623S',
#  '77 St': 'R43S',
#  '68 St-Hunter College': '628S',
#  '59 St': 'R41S',
#  '51 St': '630S',
#  'Grand Central-42 St': '901S',
#  '33 St': '632S',
#  '14 St-Union Sq': 'R20S',
#  'Astor Pl': '636S',
#  'Bleecker St': '637S',
#  'Spring St': 'A33S',
#  'Brooklyn Bridge-City Hall': '640S',
#  'Flushing-Main St': '701S',
#  'Mets-Willets Point': '702S',
#  '111 St': 'J13S',
#  '103 St-Corona Plaza': '706S',
#  'Junction Blvd': '707S',
#  '90 St-Elmhurst Av': '708S',
#  '82 St-Jackson Hts': '709S',
#  '74 St-Broadway': '710S',
#  '69 St': '711S',
#  '61 St-Woodside': '712S',
#  '52 St': '713S',
#  '46 St-Bliss St': '714S',
#  '40 St-Lowery St': '715S',
#  '33 St-Rawson St': '716S',
#  'Queensboro Plaza': 'R09S',
#  'Court Sq': 'G22S',
#  'Hunters Point Av': '720S',
#  'Vernon Blvd-Jackson Av': '721S',
#  '5 Av': '724S',
#  '34 St-Hudson Yards': '726S',
#  'Inwood-207 St': 'A02S',
#  '190 St': 'A05S',
#  '175 St': 'A07S',
#  '168 St': 'A09S',
#  '163 St-Amsterdam Av': 'A10S',
#  '155 St': 'D12S',
#  '81 St-Museum of Natural History': 'A21S',
#  '42 St-Port Authority Bus Terminal': 'A27S',
#  'W 4 St-Wash Sq': 'D20S',
#  'High St': 'A40S',
#  'Jay St-MetroTech': 'R29S',
#  'Hoyt-Schermerhorn Sts': 'A42S',
#  'Lafayette Av': 'A43S',
#  'Clinton-Washington Avs': 'G35S',
#  'Franklin Av': 'S01S',
#  'Kingston-Throop Avs': 'A47S',
#  'Utica Av': 'A48S',
#  'Ralph Av': 'A49S',
#  'Broadway Junction': 'L22S',
#  'Liberty Av': 'A52S',
#  'Shepherd Av': 'A54S',
#  'Euclid Av': 'A55S',
#  'Grant Av': 'A57S',
#  '80 St': 'A59S',
#  '88 St': 'A60S',
#  'Rockaway Blvd': 'A61S',
#  '104 St': 'J14S',
#  'Ozone Park-Lefferts Blvd': 'A65S',
#  '21 St-Queensbridge': 'B04S',
#  'Roosevelt Island': 'B06S',
#  'Lexington Av/63 St': 'B08S',
#  '57 St': 'B10S',
#  '9 Av': 'B12S',
#  'Fort Hamilton Pkwy': 'N03S',
#  '55 St': 'B15S',
#  '62 St': 'B16S',
#  '71 St': 'B17S',
#  '18 Av': 'N05S',
#  '20 Av': 'N06S',
#  'Bay Pkwy': 'N07S',
#  '25 Av': 'B22S',
#  'Bay 50 St': 'B23S',
#  'Norwood-205 St': 'D01S',
#  'Bedford Park Blvd': 'D03S',
#  '182-183 Sts': 'D06S',
#  'Tremont Av': 'D07S',
#  '174-175 Sts': 'D08S',
#  '7 Av': 'F24S',
#  '47-50 Sts-Rockefeller Ctr': 'D15S',
#  '42 St-Bryant Pk': 'D16S',
#  '34 St-Herald Sq': 'R17S',
#  'Broadway-Lafayette St': 'D21S',
#  'Grand St': 'L12S',
#  'Prospect Park': 'D26S',
#  'Parkside Av': 'D27S',
#  'Beverley Rd': 'D29S',
#  'Cortelyou Rd': 'D30S',
#  'Newkirk Plaza': 'D31S',
#  'Avenue H': 'D32S',
#  'Avenue J': 'D33S',
#  'Avenue M': 'D34S',
#  'Kings Hwy': 'N08S',
#  'Avenue U': 'N09S',
#  'Neck Rd': 'D38S',
#  'Sheepshead Bay': 'D39S',
#  'Brighton Beach': 'D40S',
#  'Ocean Pkwy': 'D41S',
#  'W 8 St-NY Aquarium': 'D42S',
#  'Coney Island-Stillwell Av': 'D43S',
#  'World Trade Center': 'E01S',
#  'Jamaica-179 St': 'F01S',
#  '169 St': 'F02S',
#  'Parsons Blvd': 'F03S',
#  'Sutphin Blvd': 'F04S',
#  'Briarwood': 'F05S',
#  'Kew Gardens-Union Tpke': 'F06S',
#  '75 Av': 'F07S',
#  'Court Sq-23 St': 'F09S',
#  'Lexington Av/53 St': 'F11S',
#  '5 Av/53 St': 'F12S',
#  '2 Av': 'F14S',
#  'Delancey St-Essex St': 'M18S',
#  'East Broadway': 'F16S',
#  'York St': 'F18S',
#  'Carroll St': 'F21S',
#  'Smith-9 Sts': 'F22S',
#  '4 Av-9 St': 'R33S',
#  '15 St-Prospect Park': 'F25S',
#  'Ditmas Av': 'F29S',
#  'Avenue I': 'F31S',
#  'Avenue N': 'F33S',
#  'Avenue P': 'F34S',
#  'Avenue X': 'F38S',
#  'Neptune Av': 'F39S',
#  'Jamaica Center-Parsons/Archer': 'G05S',
#  'Sutphin Blvd-Archer Av-JFK Airport': 'G06S',
#  'Jamaica-Van Wyck': 'G07S',
#  'Forest Hills-71 Av': 'G08S',
#  '67 Av': 'G09S',
#  '63 Dr-Rego Park': 'G10S',
#  'Woodhaven Blvd': 'J15S',
#  'Grand Av-Newtown': 'G12S',
#  'Elmhurst Av': 'G13S',
#  'Jackson Hts-Roosevelt Av': 'G14S',
#  '65 St': 'G15S',
#  'Northern Blvd': 'G16S',
#  '46 St': 'G18S',
#  'Steinway St': 'G19S',
#  '36 St': 'R36S',
#  'Queens Plaza': 'G21S',
#  '21 St': 'G24S',
#  'Greenpoint Av': 'G26S',
#  'Nassau Av': 'G28S',
#  'Metropolitan Av': 'G29S',
#  'Broadway': 'R05S',
#  'Flushing Av': 'M12S',
#  'Myrtle-Willoughby Avs': 'G32S',
#  'Bedford-Nostrand Avs': 'G33S',
#  'Classon Av': 'G34S',
#  'Aqueduct Racetrack': 'H01S',
#  'Aqueduct-N Conduit Av': 'H02S',
#  'Howard Beach-JFK Airport': 'H03S',
#  'Broad Channel': 'H19S',
#  'Beach 67 St': 'H06S',
#  'Beach 60 St': 'H07S',
#  'Beach 44 St': 'H08S',
#  'Beach 36 St': 'H09S',
#  'Beach 25 St': 'H10S',
#  'Far Rockaway-Mott Av': 'H11S',
#  'Beach 90 St': 'H12S',
#  'Beach 98 St': 'H13S',
#  'Beach 105 St': 'H14S',
#  'Rockaway Park-Beach 116 St': 'H15S',
#  '121 St': 'J12S',
#  '85 St-Forest Pkwy': 'J16S',
#  '75 St-Elderts Ln': 'J17S',
#  'Cypress Hills': 'J19S',
#  'Crescent St': 'J20S',
#  'Norwood Av': 'J21S',
#  'Cleveland St': 'J22S',
#  'Alabama Av': 'J24S',
#  'Chauncey St': 'J28S',
#  'Halsey St': 'L19S',
#  'Gates Av': 'J30S',
#  'Kosciuszko St': 'J31S',
#  '8 Av': 'N02S',
#  '6 Av': 'L02S',
#  '3 Av': 'L05S',
#  '1 Av': 'L06S',
#  'Bedford Av': 'L08S',
#  'Lorimer St': 'M13S',
#  'Graham Av': 'L11S',
#  'Montrose Av': 'L13S',
#  'Morgan Av': 'L14S',
#  'Jefferson St': 'L15S',
#  'DeKalb Av': 'R30S',
#  'Myrtle-Wyckoff Avs': 'M08S',
#  'Wilson Av': 'L20S',
#  'Bushwick Av-Aberdeen St': 'L21S',
#  'Atlantic Av': 'L24S',
#  'Sutter Av': 'L25S',
#  'Livonia Av': 'L26S',
#  'East 105 St': 'L28S',
#  'Canarsie-Rockaway Pkwy': 'L29S',
#  'Middle Village-Metropolitan Av': 'M01S',
#  'Fresh Pond Rd': 'M04S',
#  'Forest Av': 'M05S',
#  'Seneca Av': 'M06S',
#  'Knickerbocker Av': 'M09S',
#  'Central Av': 'M10S',
#  'Myrtle Av': 'M11S',
#  'Hewes St': 'M14S',
#  'Marcy Av': 'M16S',
#  'Bowery': 'M19S',
#  'Broad St': 'M23S',
#  'New Utrecht Av': 'N04S',
#  'S.B. Coney Island': 'N12S',
#  'Astoria-Ditmars Blvd': 'R01S',
#  'Astoria Blvd': 'R03S',
#  '30 Av': 'R04S',
#  '36 Av': 'R06S',
#  '39 Av-Dutch Kills': 'R08S',
#  'Lexington Av/59 St': 'R11S',
#  '5 Av/59 St': 'R13S',
#  '57 St-7 Av': 'R14S',
#  '49 St': 'R15S',
#  '8 St-NYU': 'R21S',
#  'Prince St': 'R22S',
#  'City Hall': 'R24S',
#  'Cortlandt St': 'R25S',
#  'Whitehall St-South Ferry': 'R27S',
#  'Court St': 'R28S',
#  'Union St': 'R32S',
#  '25 St': 'R35S',
#  '45 St': 'R39S',
#  '53 St': 'R40S',
#  'Bay Ridge Av': 'R42S',
#  'Bay Ridge-95 St': 'R45S',
#  'Park Pl': 'S03S',
#  'Botanic Garden': 'S04S',
#  'Tottenville': 'S09S',
#  'Arthur Kill': 'S11S',
#  'Richmond Valley': 'S13S',
#  'Pleasant Plains': 'S14S',
#  "Prince's Bay": 'S15S',
#  'Huguenot': 'S16S',
#  'Annadale': 'S17S',
#  'Eltingville': 'S18S',
#  'Great Kills': 'S19S',
#  'Bay Terrace': 'S20S',
#  'Oakwood Heights': 'S21S',
#  'New Dorp': 'S22S',
#  'Grant City': 'S23S',
#  'Jefferson Av': 'S24S',
#  'Dongan Hills': 'S25S',
#  'Old Town': 'S26S',
#  'Grasmere': 'S27S',
#  'Clifton': 'S28S',
#  'Stapleton': 'S29S',
#  'Tompkinsville': 'S30S',
#  'St George': 'S31S'}
